# %%
#最後改良>>>1.是否將初始if判斷式改為while loop?? 2.填答時如何顯示各domain(v)/如果填指示外的字元如何處理(v) 3.結果陽性時給予主要原因(占分最高)之domain(V)
# entry criterion & ADDITVE CRITERION & 答案與分數轉換 & 分數結果判斷 基本完成
# SLE final diagnosis
def SLE(total_score):
  if total_score >= 10:
    return f'''Yes. This patient is classified as SLE.
    Main causes: (1)clinical: {main_clinical_cause} ； (2)immunology: {main_immunological_cause}
    Each gets {highest} pts of total {total_score} pts and accounts for {highest/total_score * 100:.2f} % of total weights.'''
  else:
    return "No. This patient is not classified as SLE."
#clinical domains & criteria
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#Immunology domains & criteria
Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
SLE_specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}
#clinical & immunological
clinical = ['Constitutional', 'Hematologic', 'Neuropsychiatric', 'Mucocutaneous', 'Serosal', 'Musculoskeletal', 'Renal']
immunological = ['Antiphospholipid_antibodies', 'Complement_proteins', 'SLE_specific_antibodies']
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#Immunological_Q
immunological_Q = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_Q)):
  immunological_Q[i] = immunological_Q[i].keys()
#clinical_weight
clinical_trueweight = []
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
  clinical_trueweight.append(clinical_weight[i].copy()) 
  clinical_trueweight[i][0:len(clinical_trueweight[i])] = [None] * len(clinical_trueweight[i])
#immunological_weight
immunological_trueweight = [] 
immunological_weight = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(len(immunological_weight)):
  immunological_weight[i] = list(immunological_weight[i].values())
  immunological_trueweight.append(immunological_weight[i].copy())
  immunological_trueweight[i][0:len(immunological_trueweight[i])] = [None] * len(immunological_trueweight[i])
#Ans
Ans_clinical = [[], [], [], [], [], [], []]  #想讓答案初始值設為None(上面已完成)
Ans_immunological = [[], [], []]

#entry criterion
print('Welcome to SLE diagnosis assistant!')
print('Here comes entry criteron.')
titer = float(input('ANA at a titer of 1:"?" on HEp-2 cells.'))
if titer <= 80:   #記得後面要縮排>>考慮改良為while loop
  print('Additive criteria are needed before final diagnosis.')
  print('''The following are some important conditions in clinical or immunological domains.
   Please input "Y" if a patient meets the condition while input "N" if one doesn't.''')
  #嘗試利用for loop處理與醫師問答和答案紀錄
  print("First, we need to know the patient's clinical conditions through the following questionaire.")
  for i in range(0, len(clinical)):
    print('{0}. Questions about {1} domain:'.format(i+1, clinical[i])) #字串格式化
    for condition in clinical_Q[i]:
      print(condition, '?')
      Ans_clinical[i] += input( 'Please input "Y" or "N".' )
  print("Ans_clinical: ", Ans_clinical)

  print("Then, we would like to further understand the patient's immunological conditions through the following questionaire.")
  for i in range(0, len(immunological_Q)):
    print(f'{i+1}. Questions about {immunological[i]} domain:')
    for condition in immunological_Q[i]:
      print(condition, '?')
      Ans_immunological[i] += input( 'Please input "Y" or "N".' )
  print("Ans_immunological: ", Ans_immunological)

  #處理clinical domains的weights
  for i in range(len(Ans_clinical)):
    for j in range(len(Ans_clinical[i])):
      if Ans_clinical[i][j] == "Y":
        clinical_trueweight[i][j] = clinical_weight[i][j]
      elif Ans_clinical[i][j] == "N":
        clinical_trueweight[i][j] = 0          #要是非N、Y怎麼辦，如何讓他重填
      else:
        print('''You filled in wrong key words(not "Y" or "N") in the questionaire, so the result may be wrong.
        We suggest that you restart the system again and be more careful!''')
  print("clinical_trueweight: ", clinical_trueweight)   
  #處理immunological domains的weights
  for i in range(len(Ans_immunological)):
    for j in range(len(Ans_immunological[i])):
      if Ans_immunological[i][j] == "Y":
        immunological_trueweight[i][j] = immunological_weight[i][j]
      elif Ans_immunological[i][j] == "N":
        immunological_trueweight[i][j] = 0
      else:
        print('''You filled in wrong key words(not "Y" or "N") in the questionaire, so the result may be wrong.
        We suggest that you restart the system again and be more careful!''')
  print("immunological_trueweight: ", immunological_trueweight) 
  clinical_trueweight2 = [] 
  immunological_trueweight2 = []
  for weight_list in clinical_trueweight:
    clinical_trueweight2.append(max(weight_list)) 
  for weight_list in immunological_trueweight:
    immunological_trueweight2.append(max(weight_list))
  print("clinical_trueweight2: ", clinical_trueweight2)  # >>>自己檢查用
  print("immunological_trueweight2: ", immunological_trueweight2)
  clinical_total_score = sum(clinical_trueweight2)
  immunological_total_score = sum(immunological_trueweight2)
  total_score = clinical_total_score + immunological_total_score
  # 找到weght最高的domain(想想如何呈現前三高)
  highest_clinical = max(clinical_trueweight2)
  highest_immunological = max(immunological_trueweight2)
  highest = highest_clinical if highest_clinical > highest_immunological else highest_immunological
  main_clinical_cause = []
  main_immunological_cause = []
  for i in range(len(clinical_trueweight2)):
    if clinical_trueweight2[i] == highest:
      main_clinical_cause.append(f'{clinical[i]} domain')
  for j in range(len(immunological_trueweight2)):
    if immunological_trueweight2[j] == highest:
      main_immunological_cause.append(f'{immunological[j]} domain') 
  main_clinical_cause = tuple(main_clinical_cause)     
  main_immunological_cause = tuple(main_immunological_cause)
  print('main_clinical_cause:', main_clinical_cause) ##N
  print('main_immunological_cause:', main_immunological_cause)
  print("clinical_total_score:", clinical_total_score)
  print("immunological_total_score: ", immunological_total_score)
  print("total_score: ", total_score)
  print(SLE(total_score))
else:
  print('This patient is not classified as SLE!')
# Out:
# Welcome to SLE diagnosis assistant!
# Here comes entry criteron.
# ANA at a titer of 1:"?" on HEp-2 cells.70
# Additive criteria are needed before final diagnosis.
# The following are some important conditions in clinical or immunological domains.
#    Please input "Y" if a patient meets the condition while input "N" if one doesn't.
# First, we need to know the patient's clinical conditions through the following questionaire.
# 1. Questions about Constitutional domain:
# Fever ?
# Please input "Y" or "N".Y
# 2. Questions about Hematologic domain:
# Leukopenia ?
# Please input "Y" or "N".N
# Thrombocytopenia ?
# Please input "Y" or "N".N
# Autoimmune hemolysis ?
# Please input "Y" or "N".N
# 3. Questions about Neuropsychiatric domain:
# Delirium ?
# Please input "Y" or "N".N
# Psychosis ?
# Please input "Y" or "N".Y
# Siezure ?
# Please input "Y" or "N".Y
# 4. Questions about Mucocutaneous domain:
# Non-scarring alopecia ?
# Please input "Y" or "N".N
# Oral ulcers ?
# Please input "Y" or "N".Y
# Subacute cutaneous OR discoid lupus ?
# Please input "Y" or "N".Y
# Acute cutaneous lupus ?
# Please input "Y" or "N".Y
# 5. Questions about Serosal domain:
# Pleural or pericardial effusion ?
# Please input "Y" or "N".N
# Acute pericarditis ?
# Please input "Y" or "N".Y
# 6. Questions about Musculoskeletal domain:
# Joint involvment ?
# Please input "Y" or "N".Y
# 7. Questions about Renal domain:
# Proteinuria > 0.5g/24h ?
# Please input "Y" or "N".N
# Renal biopsy Class II or V lupus nephritis ?
# Please input "Y" or "N".N
# Renal biopsy Class III or IV lupus nephritis ?
# Please input "Y" or "N".N
# Ans_clinical:  [['Y'], ['N', 'N', 'N'], ['N', 'Y', 'Y'], ['N', 'Y', 'Y', 'Y'], ['N', 'Y'], ['Y'], ['N', 'N', 'N']]
# Then, we would like to further understand the patient's immunological conditions through the following questionaire.
# 1. Questions about Antiphospholipid_antibodies domain:
# Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant ?
# Please input "Y" or "N".N
# 2. Questions about Complement_proteins domain:
# Low C3 OR low C4 ?
# Please input "Y" or "N".Y
# Low C3 AND low C4 ?
# Please input "Y" or "N".N
# 3. Questions about SLE_specific_antibodies domain:
# Anti-dsDNA antibody OR Anti-Smith antibody ?
# Please input "Y" or "N".Y
# Ans_immunological:  [['N'], ['Y', 'N'], ['Y']]
# clinical_trueweight:  [[2], [0, 0, 0], [0, 3, 5], [0, 2, 4, 6], [0, 6], [6], [0, 0, 0]]
# immunological_trueweight:  [[0], [3, 0], [6]]
# clinical_trueweight2:  [2, 0, 5, 6, 6, 6, 0]
# immunological_trueweight2:  [0, 3, 6]
# main_clinical_cause: ('Mucocutaneous domain', 'Serosal domain', 'Musculoskeletal domain')
# main_immunological_cause: ('SLE_specific_antibodies domain',)
# clinical_total_score: 25
# immunological_total_score:  9
# total_score:  34
# Yes. This patient is classified as SLE.
#     Main causes: (1)clinical: ('Mucocutaneous domain', 'Serosal domain', 'Musculoskeletal domain') ； (2)immunology: ('SLE_specific_antibodies domain',)
#     Each gets 6 pts of total 34 pts, and accounts for 17.65 % of total weights.

# %%
#字串格式化
#clinical domains & criteria
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#Immunology domains & criteria
Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
SLE_specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}
#clinical & immunological
clinical = ['Constitutional', 'Hematologic', 'Neuropsychiatric', 'Mucocutaneous', 'Serosal', 'Musculoskeletal', 'Renal']
immunological = ['Antiphospholipid_antibodies', 'Complement_proteins', 'SLE_specific_antibodies']
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#Immunological_Q
immunological_Q = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_Q)):
  immunological_Q[i] = immunological_Q[i].keys()
#clinical_weight
clinical_trueweight = []
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
  clinical_trueweight.append(clinical_weight[i].copy()) 
  clinical_trueweight[i][0:len(clinical_trueweight[i])] = [None] * len(clinical_trueweight[i])
#immunological_weight
immunological_trueweight = [] 
immunological_weight = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(len(immunological_weight)):
  immunological_weight[i] = list(immunological_weight[i].values())
  immunological_trueweight.append(immunological_weight[i].copy())
  immunological_trueweight[i][0:len(immunological_trueweight[i])] = [None] * len(immunological_trueweight[i])
#Ans
Ans_clinical = [[], [], [], [], [], [], []]  #想讓答案初始值設為None(上面已完成)
Ans_immunological = [[], [], []]

#entry criterion
print('Welcome to SLE diagnosis assistant!')
print('Here comes entry criteron.')
titer = float(input('ANA at a titer of 1:"?" on HEp-2 cells.'))
if titer <= 80:   #記得後面要縮排>>考慮改良為while loop
  print('Additive criteria are needed before final diagnosis.')
  print('''The following are some important conditions in clinical or immunological domains.
   Please input "Y" if a patient meets the condition while input "N" if one doesn't.''')
  #嘗試利用for loop處理與醫師問答和答案紀錄
  print("First, we need to know the patient's clinical conditions through the following questionaire.")
  for i in range(0, len(clinical)):
    print('{0}. Questions about {1} domain:'.format(i+1, clinical[i]))
    for condition in clinical_Q[i]:
      print(condition, '?')
      Ans_clinical[i] += input( 'Please input "Y" or "N".' )
  print("Ans_clinical: ", Ans_clinical)

  print("Then, we would like to further understand the patient's immunological conditions through the following questionaire.")
  for i in range(0, len(immunological_Q)):
    print(f'{i+1}. Questions about {immunological[i]} domain:')
    for condition in immunological_Q[i]:
      print(condition, '?')
      Ans_immunological[i] += input( 'Please input "Y" or "N".' )
  print("Ans_immunological: ", Ans_immunological)
# Out:
# Welcome to SLE diagnosis assistant!
# Here comes entry criteron.
# ANA at a titer of 1:"?" on HEp-2 cells.70
# Additive criteria are needed before final diagnosis.
# The following are some important conditions in clinical or immunological domains.
#    Please input "Y" if a patient meets the condition while input "N" if one doesn't.
# First, we need to know the patient's clinical conditions through the following questionaire.
# 1. Questions about Constitutional domain:
# Fever ?
# Please input "Y" or "N".Y
# 2. Questions about Hematologic domain:
# Leukopenia ?
# Please input "Y" or "N".Y
# Thrombocytopenia ?
# Please input "Y" or "N".N
# Autoimmune hemolysis ?
# Please input "Y" or "N".N
# 3. Questions about Neuropsychiatric domain:
# Delirium ?
# Please input "Y" or "N".Y
# Psychosis ?
# Please input "Y" or "N".Y
# Siezure ?
# Please input "Y" or "N".Y
# 4. Questions about Mucocutaneous domain:
# Non-scarring alopecia ?
# Please input "Y" or "N".N
# Oral ulcers ?
# Please input "Y" or "N".N
# Subacute cutaneous OR discoid lupus ?
# Please input "Y" or "N".Y
# Acute cutaneous lupus ?
# Please input "Y" or "N".Y
# 5. Questions about Serosal domain:
# Pleural or pericardial effusion ?
# Please input "Y" or "N".N
# Acute pericarditis ?
# Please input "Y" or "N".N
# 6. Questions about Musculoskeletal domain:
# Joint involvment ?
# Please input "Y" or "N".Y
# 7. Questions about Renal domain:
# Proteinuria > 0.5g/24h ?
# Please input "Y" or "N".Y
# Renal biopsy Class II or V lupus nephritis ?
# Please input "Y" or "N".N
# Renal biopsy Class III or IV lupus nephritis ?
# Please input "Y" or "N".Y
# Ans_clinical:  [['Y'], ['Y', 'N', 'N'], ['Y', 'Y', 'Y'], ['N', 'N', 'Y', 'Y'], ['N', 'N'], ['Y'], ['Y', 'N', 'Y']]
# Then, we would like to further understand the patient's immunological conditions through the following questionaire.
# 1. Questions about Antiphospholipid_antibodies domain:
# Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant ?
# Please input "Y" or "N".N
# 2. Questions about Complement_proteins domain:
# Low C3 OR low C4 ?
# Please input "Y" or "N".Y
# Low C3 AND low C4 ?
# Please input "Y" or "N".N
# 3. Questions about SLE_specific_antibodies domain:
# Anti-dsDNA antibody OR Anti-Smith antibody ?
# Please input "Y" or "N".N
# Ans_immunological:  [['N'], ['Y', 'N'], ['N']]

# %%
#clinical domains & criteria >>改良2-1: 將問題domain顯示出來
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#Immunology domains & criteria
Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
SLE_specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}
#clinical & immunological
clinical = ['Constitutional', 'Hematologic', 'Neuropsychiatric', 'Mucocutaneous', 'Serosal', 'Musculoskeletal', 'Renal']
immunological = ['Antiphospholipid_antibodies', 'Complement_proteins', 'SLE_specific_antibodies']
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#Immunological_Q
immunological_Q = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_Q)):
  immunological_Q[i] = immunological_Q[i].keys()
#clinical_weight
clinical_trueweight = []
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
  clinical_trueweight.append(clinical_weight[i].copy()) 
  clinical_trueweight[i][0:len(clinical_trueweight[i])] = [None] * len(clinical_trueweight[i])
#immunological_weight
immunological_trueweight = [] 
immunological_weight = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(len(immunological_weight)):
  immunological_weight[i] = list(immunological_weight[i].values())
  immunological_trueweight.append(immunological_weight[i].copy())
  immunological_trueweight[i][0:len(immunological_trueweight[i])] = [None] * len(immunological_trueweight[i])
#Ans
Ans_clinical = [[], [], [], [], [], [], []]  #想讓答案初始值設為None(上面已完成)
Ans_immunological = [[], [], []]

#entry criterion
print('Welcome to SLE diagnosis assistant!')
print('Here comes entry criteron.')
titer = float(input('ANA at a titer of 1:"?" on HEp-2 cells.'))
if titer <= 80:   #記得後面要縮排>>考慮改良為while loop
  print('Additive criteria are needed before final diagnosis.')
  print('''The following are some important conditions in clinical or immunological domains.
   Please input "Y" if a patient meets the condition while input "N" if one doesn't.''')
  #嘗試利用for loop處理與醫師問答和答案紀錄
  print("First, we need to know the patient's clinical conditions through the following questionaire.")
  for i in range(0, len(clinical)):
    print(i+1,'.', 'Questions about', clinical[i], 'domain')
    for condition in clinical_Q[i]:
      print(condition, '?')
      Ans_clinical[i] += input( 'Please input "Y" or "N".' )
  print("Ans_clinical: ", Ans_clinical)

  print("Then, we would like to further understand the patient's immunological conditions through the following questionaire.")
  for i in range(0, len(immunological_Q)):
    print(i+1,'.', 'Questions about', immunological[i], 'domain')
    for condition in immunological_Q[i]:
      print(condition, '?')
      Ans_immunological[i] += input( 'Please input "Y" or "N".' )
  print("Ans_immunological: ", Ans_immunological)
# Out:
# Welcome to SLE diagnosis assistant!
# Here comes entry criteron.
# ANA at a titer of 1:"?" on HEp-2 cells.50
# Additive criteria are needed before final diagnosis.
# The following are some important conditions in clinical or immunological domains.
#    Please input "Y" if a patient meets the condition while input "N" if one doesn't.
# First, we need to know the patient's clinical conditions through the following questionaire.
# 1 . Questions about Constitutional domain
# Fever ?
# Please input "Y" or "N".Y
# 2 . Questions about Hematologic domain
# Leukopenia ?
# Please input "Y" or "N".Y
# Thrombocytopenia ?
# Please input "Y" or "N".N
# Autoimmune hemolysis ?
# Please input "Y" or "N".Y
# 3 . Questions about Neuropsychiatric domain
# Delirium ?
# Please input "Y" or "N".N
# Psychosis ?
# Please input "Y" or "N".N
# Siezure ?
# Please input "Y" or "N".Y
# 4 . Questions about Mucocutaneous domain
# Non-scarring alopecia ?
# Please input "Y" or "N".N
# Oral ulcers ?
# Please input "Y" or "N".N
# Subacute cutaneous OR discoid lupus ?
# Please input "Y" or "N".N
# Acute cutaneous lupus ?
# Please input "Y" or "N".Y
# 5 . Questions about Serosal domain
# Pleural or pericardial effusion ?
# Please input "Y" or "N".Y
# Acute pericarditis ?
# Please input "Y" or "N".Y
# 6 . Questions about Musculoskeletal domain
# Joint involvment ?
# Please input "Y" or "N".N
# 7 . Questions about Renal domain
# Proteinuria > 0.5g/24h ?
# Please input "Y" or "N".N
# Renal biopsy Class II or V lupus nephritis ?
# Please input "Y" or "N".Y
# Renal biopsy Class III or IV lupus nephritis ?
# Please input "Y" or "N".N
# Ans_clinical:  [['Y'], ['Y', 'N', 'Y'], ['N', 'N', 'Y'], ['N', 'N', 'N', 'Y'], ['Y', 'Y'], ['N'], ['N', 'Y', 'N']]
# Then, we would like to further understand the patient's immunological conditions through the following questionaire.
# 1 . Questions about Antiphospholipid_antibodies domain
# Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant ?
# Please input "Y" or "N".N
# 2 . Questions about Complement_proteins domain
# Low C3 OR low C4 ?
# Please input "Y" or "N".N
# Low C3 AND low C4 ?
# Please input "Y" or "N".Y
# 3 . Questions about SLE_specific_antibodies domain
# Anti-dsDNA antibody OR Anti-Smith antibody ?
# Please input "Y" or "N".Y
# Ans_immunological:  [['N'], ['N', 'Y'], ['Y']]

# %%
#clinical domains & criteria
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#Immunology domains & criteria
Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
SLE_specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#Immunological_Q
immunological_Q = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_Q)):
  immunological_Q[i] = immunological_Q[i].keys()
#clinical_weight
clinical_trueweight = []
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
  clinical_trueweight.append(clinical_weight[i].copy()) 
  clinical_trueweight[i][0:len(clinical_trueweight[i])] = [None] * len(clinical_trueweight[i])
#immunological_weight
immunological_trueweight = [] 
immunological_weight = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(len(immunological_weight)):
  immunological_weight[i] = list(immunological_weight[i].values())
  immunological_trueweight.append(immunological_weight[i].copy())
  immunological_trueweight[i][0:len(immunological_trueweight[i])] = [None] * len(immunological_trueweight[i])
print(clinical_trueweight)
print(immunological_trueweight)
# Out:
# [[None], [None, None, None], [None, None, None], [None, None, None, None], [None, None], [None], [None, None, None]]
# [[None], [None, None], [None]]

# %%
a = [1, 2, 4, 3]
a[0:len(a)] = [None] * len(a)
a
# Out:
# [None, None, None, None]

# %%
# b = [2, 2, 4, 3]
# a = []
# a[0] = b[0] #list assignment index out of range
# a
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-2d2c4f453707> in <module>()
#       1 b = [2, 2, 4, 3]
#       2 a = []
# ----> 3 a[0] = b[0]
#       4 a
#
# IndexError: list assignment index out of range

# %%
# entry criterion & ADDITVE CRITERION & 答案與分數轉換 & 分數結果判斷 基本完成
# SLE final diagnosis
def SLE(total_score):
  if total_score >= 10:
    return "Yes. This patient is classified as SLE."
  else:
    return "No. This patient is not classified as SLE."
#clinical domains & criteria
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#Immunology domains & criteria
Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
SLE_specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#Immunological_Q
immunological_Q = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_Q)):
  immunological_Q[i] = immunological_Q[i].keys()
#clinical_weight
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
clinical_trueweight = clinical_weight.copy()
#immunological_weight
immunological_weight = [Antiphospholipid_antibodies, Complement_proteins, SLE_specific_antibodies]
for i in range(0, len(immunological_weight)):
  immunological_weight[i] = list(immunological_weight[i].values())
immunological_trueweight = immunological_weight.copy()
#Ans
Ans_clinical = [[], [], [], [], [], [], []]
Ans_immunological = [[], [], []]

#entry criterion
print('Welcome to SLE diagnosis assistant!')
print('Here comes entry criteron.')
titer = float(input('ANA at a titer of 1:"?" on HEp-2 cells.'))
if titer <= 80:   #記得後面要縮排>>考慮改良為while loop
  print('Additive criteria are needed before final diagnosis.')
  print('''The following are some important conditions in clinical or immunological domains.
   Please input "Y" if a patient meets the condition while input "N" if one doesn't.''')
else:
  print('This patient is not classified as SLE!')
#嘗試利用for loop處理與醫師問答和答案紀錄
print("First, we need to know the patient's clinical conditions through the following questionaire.")
for i in range(0, len(clinical_Q)):
  for condition in clinical_Q[i]:
    print(condition, '?')
    Ans_clinical[i] += input( 'Please input "Y" or "N".' )
print(Ans_clinical)

print("Then, we would like to further understand the patient's immunological conditions through the following questionaire.")
for i in range(0, len(immunological_Q)):
  for condition in immunological_Q[i]:
    print(condition, '?')
    Ans_immunological[i] += input( 'Please input "Y" or "N".' )
print(Ans_immunological)

#處理clinical domains的weights
for i in range(len(Ans_clinical)):
  for j in range(len(Ans_clinical[i])):
    if Ans_clinical[i][j] == "Y":
      clinical_trueweight[i][j] = clinical_weight[i][j]
    else:
      clinical_trueweight[i][j] = 0
print(clinical_trueweight)   
#處理immunological domains的weights
for i in range(len(Ans_immunological)):
  for j in range(len(Ans_immunological[i])):
    if Ans_immunological[i][j] == "Y":
      immunological_trueweight[i][j] = immunological_weight[i][j]
    else:
      immunological_trueweight[i][j] = 0
print(immunological_trueweight) 
clinical_trueweight2 = [] 
immunological_trueweight2 = []
for weight_list in clinical_trueweight:
  clinical_trueweight2.append(max(weight_list)) 
for weight_list in immunological_trueweight:
  immunological_trueweight2.append(max(weight_list))
print(clinical_trueweight2)  # >>>自己檢查用
print(immunological_trueweight2)
clinical_total_score = sum(clinical_trueweight2)
immunological_total_score = sum(immunological_trueweight2)
total_score = clinical_total_score + immunological_total_score
print(clinical_total_score)
print(immunological_total_score)
print(total_score)
print(SLE(total_score))
# Out:
# Welcome to SLE diagnosis assistant!
# Here comes entry criteron.
# ANA at a titer of 1:"?" on HEp-2 cells.81
# This patient is not classified as SLE!
# First, we need to know the patient's clinical conditions through the following questionaire.
# Fever ?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-4a2c099d5c1b> in <module>()
#      55   for condition in clinical_Q[i]:
#      56     print(condition, '?')
# ---> 57     Ans_clinical[i] += input( 'Please input "Y" or "N".' )
#      58 print(Ans_clinical)
#      59
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
#clinical_weight
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_weight)):
  clinical_weight[i] = list(clinical_weight[i].values())
clinical_trueweight = clinical_weight.copy()
print(clinical_weight)
print(clinical_trueweight)
# Out:
# [[2], [3, 4, 4], [2, 3, 5], [2, 2, 4, 6], [5, 6], [6], [4, 8, 10]]
# [[2], [3, 4, 4], [2, 3, 5], [2, 2, 4, 6], [5, 6], [6], [4, 8, 10]]

# %%
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#clinical_weight
clinical_weight = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_weight)):
  clinical_weight[i] = clinical_weight[i].values()
print(clinical_weight)
# Out:
# [dict_values([2]), dict_values([3, 4, 4]), dict_values([2, 3, 5]), dict_values([2, 2, 4, 6]), dict_values([5, 6]), dict_values([6]), dict_values([4, 8, 10])]

# %%
#debug try
Ans_clinical = [[], [], [], [], [], [], []]
Constitutional = {'Fever':2}
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
Musculoskeletal = {'Joint involvment':6}
Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
#clinical_Q
clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
for i in range(0, len(clinical_Q)):
  clinical_Q[i] = clinical_Q[i].keys()
for i in range(0, len(clinical_Q)):
  for condition in clinical_Q[i]:
    print(condition, '?')
# Out:
# Fever ?
# Leukopenia ?
# Thrombocytopenia ?
# Autoimmune hemolysis ?
# Delirium ?
# Psychosis ?
# Siezure ?
# Non-scarring alopecia ?
# Oral ulcers ?
# Subacute cutaneous OR discoid lupus ?
# Acute cutaneous lupus ?
# Pleural or pericardial effusion ?
# Acute pericarditis ?
# Joint involvment ?
# Proteinuria > 0.5g/24h ?
# Renal biopsy Class II or V lupus nephritis ?
# Renal biopsy Class III or IV lupus nephritis ?

# %%
Ans_Hematologic = []
Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
Hematologic_Q = Hematologic.keys()
for condition in Hematologic_Q:
  print(condition, '?')
  Ans_Hematologic += input( 'Please input "Y" or "N".' )
print(Ans_Hematologic)
# Out:
# Leukopenia ?
# Please input "Y" or "N".Y
# Thrombocytopenia ?
# Please input "Y" or "N".Y
# Autoimmune hemolysis ?
# Please input "Y" or "N".Y
# ['Y', 'Y', 'Y']

# %%
# def SLE(total_score):
#   if total_score >= 10:
#     return "Yes. This patient is classified as SLE."
#   else:
#     return "No. This patient is not classified as SLE."
# print(SLE(4))

#clinical domains & criteria
# Constitutional = {'Fever':2}
# Hematologic = {'Leukopenia':3, 'Thrombocytopenia':4, 'Autoimmune hemolysis':4}
# Neuropsychiatric = {'Delirium':2, 'Psychosis':3, 'Siezure':5}
# Mucocutaneous = {'Non-scarring alopecia':2, 'Oral ulcers':2, 'Subacute cutaneous OR discoid lupus':4, 'Acute cutaneous lupus':6}
# Serosal = {'Pleural or pericardial effusion':5, 'Acute pericarditis':6}
# Musculoskeletal = {'Joint involvment':6}
# Renal = {'Proteinuria > 0.5g/24h':4, 'Renal biopsy Class II or V lupus nephritis':8, 'Renal biopsy Class III or IV lupus nephritis':10}
# #clinical_Q
# clinical_Q = [Constitutional, Hematologic, Neuropsychiatric, Mucocutaneous, Serosal, Musculoskeletal, Renal]
# Ans_clinical = []
# for domain in clinical_Q:
#   clinical_Q[domain] = clinical_Q[domain].keys()

for domain in clinical_Q:
  for condition in clinical_Q[domain]:
    print(condition, '?')
    Ans_clinical += input( 'Please input "Y" or "N".' )
print(Ans_clinical)
  
#Immunology domains & criteria
# Antiphospholipid_antibodies = {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodes OR Lupus anticoagulant':2}
# Complement_proteins = {'Low C3 OR low C4':3, 'Low C3 AND low C4':4}
# SLE-specific_antibodies = {'Anti-dsDNA antibody OR Anti-Smith antibody':6}


# print('Welcome to SLE diagnosis assistant!')
# print('Here comes entry criteron.')
# titer = float(input('ANA at a titer of 1:"?" on HEp-2 cells.'))
# if titer <= 80:
#   print('Additive criteria are needed before final diagnosis.')
#   print('''The following are some important conditions in clinical or immunological domains.
#    Please input "Y" if a patient meets the condition while input "N" if one doesn't.''')
#   while 1 <= i <= len():
#   a = [Constitutional_Q, Hematologic_Q, Neuropsychiatric_Q]???
# else:
#   print('This patient is not classified as SLE!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-fd4f4d0d5bdd> in <module>()
#      21
#      22 for domain in clinical_Q:
# ---> 23   for condition in clinical_Q[domain]:
#      24     print(condition, '?')
#      25     Ans_clinical += input( 'Please input "Y" or "N".' )
#
# TypeError: list indices must be integers or slices, not dict_keys
